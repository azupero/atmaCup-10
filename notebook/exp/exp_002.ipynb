# %% [markdown]
# # exp_002

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import plotly
from plotly import express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import texthero as hero
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import KFold, StratifiedKFold
from gensim.models import word2vec, KeyedVectors
from sklearn.pipeline import Pipeline
from pathlib import Path
from typing import Union, Tuple, List
from tqdm import tqdm
import lightgbm as lgb
import category_encoders as ce
import wandb
from wandb.lightgbm import wandb_callback

import sys
sys.path.append('../../src')
import utils

logger = utils.get_logger()

tqdm.pandas()

INPUT_DIR = "../../input"
OUTPUT_DIR = "../../output"
EXP_NAME = "exp_002"

OBJECT_ID = "object_id"

# wandb.init(project="atmacup-10", name=EXP_NAME)
# Out:
# [2021-04-04 22:25:15,465] [INFO] [logger set up]

# %%
class ArtDataset(object):
    def __init__(self, file_path: Path):
        self.target = 'likes'
        self.file_path = file_path
        self.train_df = pd.read_csv(self.file_path / 'train.csv')
        self.test_df = pd.read_csv(self.file_path / 'test.csv')
        self.color_df = pd.read_csv(self.file_path / 'color.csv')
        self.historical_df = pd.read_csv(self.file_path / 'historical_person.csv')
        self.maker_df = pd.read_csv(self.file_path / 'maker.csv')
        self.material_df = pd.read_csv(self.file_path / 'material.csv')
        self.object_df = pd.read_csv(self.file_path / 'object_collection.csv')
        self.palette_df = pd.read_csv(self.file_path / 'palette.csv')
        self.principal_occupation_df = pd.read_csv(self.file_path / 'principal_maker_occupation.csv')
        self.principal_maker_df =  pd.read_csv(self.file_path / 'principal_maker.csv')
        self.production_df = pd.read_csv(self.file_path / 'production_place.csv')
        self.technique_df = pd.read_csv(self.file_path / 'technique.csv')
        self.submission = pd.read_csv(self.file_path / 'sample_submission.csv')

    def get_whole_df(self):
        return pd.concat([self.train_df, self.test_df], axis=0).reset_index(drop=True)

    def get_target(self, log: bool = False):
        return np.log1p(self.train_df[self.target].values) if log else self.train_df[self.target].values

art_ds = ArtDataset(file_path=Path(INPUT_DIR))

# %% [markdown]
# ## table / aggregation feature

# %%
class BaseBlock(object):
    def fit(self, input_df: pd.DataFrame, y=None) -> pd.DataFrame:
        return self.transform(input_df)

    def transform(self, input_df: pd.DataFrame) -> pd.DataFrame:
        return NotImplementedError()


class OrdinalEncodingBlock(BaseBlock):
    def __init__(self, cat_cols: list):
        self.cat_cols = cat_cols
        self.encoder = None

    def fit(self, input_df: pd.DataFrame, y=None):
        self.encoder = ce.OrdinalEncoder(handle_unknown="value", handle_missing="value")
        self.encoder.fit(input_df[self.cat_cols])
        return self.transform(input_df)

    def transform(self, input_df: pd.DataFrame):
        return (
            self.encoder.transform(input_df[self.cat_cols])
            .add_prefix("OE_")
            .astype(int)
        )


class CountEncodingBlock(BaseBlock):
    def __init__(self, cat_cols: list):
        self.cat_cols = cat_cols
        self.encoder = None

    def fit(self, input_df: pd.DataFrame, y=None):
        self.encoder = ce.CountEncoder(handle_unknown=-1, handle_missing="count")
        self.encoder.fit(input_df[self.cat_cols])
        return self.transform(input_df)

    def transform(self, input_df: pd.DataFrame):
        return self.encoder.transform(input_df[self.cat_cols]).add_prefix("CE_")


class TargetEncodingBlock(BaseBlock):
    '''TargetEncoding
    - mapping_dfはtest setに対する変換のため(train全体でTE)
    - xfeatのTargetEncodingはoofにしかない水準の時の値が0になる仕様なのでoof平均で埋めるようにしている
    '''
    def __init__(self, columns: List[str], target_column: str, cv: List):
        self.columns = columns
        self.target_column = target_column
        self.cv = cv
        self.num_fold = len(self.cv)

    def create_mapping(self, input_df: pd.DataFrame, y: np.ndarray):
        self.mapping_df = {}
        self.y_mean = np.mean(y)
        output_df = pd.DataFrame()

        for col in self.columns:
            keys = input_df[col].unique()
            oof = np.zeros_like(input_df[col], dtype=float)

            for train_idx, valid_idx in self.cv:
                _df = input_df.iloc[train_idx].groupby([col])[self.target_column].mean()
                _df = _df.reindex(keys)
                _df = _df.fillna(_df.mean())
                oof[valid_idx] = input_df.iloc[valid_idx][col].map(_df.to_dict())

            output_df[col] = oof

            self.mapping_df[col] = input_df.groupby([col])[self.target_column].mean()

        return output_df

    def fit(self, input_df: pd.DataFrame, y=None):
        output_df = self.create_mapping(input_df, y)

        return output_df.add_prefix("TE_")

    def transform(self, input_df: pd.DataFrame):
        output_df = pd.DataFrame()

        for col in self.columns:
            output_df[col] = input_df[col].map(self.mapping_df[col]).fillna(self.y_mean)

        return output_df.add_prefix("TE_")


def merge_by_key(left: Union[pd.DataFrame, pd.Series], right: pd.DataFrame, on=OBJECT_ID) -> pd.DataFrame:
    if not isinstance(left, pd.Series):
        left = left[on]
    return pd.merge(left, right, on=on, how='left').drop(columns=[on])


class OtherTableCountBlock(BaseBlock):
    '''material, technique, production_place, historical_personのcrosstab集計
    - nameが被集計対象
    '''
    def __init__(self, category_df: pd.DataFrame, df_name: str, minimum_freq: int) -> None:
        self.category_df = category_df
        self.df_name = df_name
        self.minimum_freq = minimum_freq

    def fit(self, input_df: pd.DataFrame, y=None):
        vc = self.category_df["name"].value_counts()
        use_names = vc[vc >= self.minimum_freq].index
        _df = self.category_df[self.category_df["name"].isin(use_names)].reset_index(drop=True)
        self.agg_df = pd.crosstab(_df["object_id"], _df["name"]).reset_index()

        return self.transform(input_df)

    def transform(self, input_df: pd.DataFrame):
        output_df = merge_by_key(input_df, self.agg_df).fillna(0).astype(int)
        return output_df.add_prefix(f"OtherTableCount_{self.df_name}_")


def detect_size_from_subtitle(input_df: pd.DataFrame):
    output_df = pd.DataFrame()
    for axis in ['h', 'w', 't', 'd']:
        column_name = f'size_{axis}'
        size_info = input_df['sub_title'].str.extract(r'{} (\d*|\d*\.\d*)(cm|mm)'.format(axis)) # 正規表現を使ってサイズを抽出
        size_info = size_info.rename(columns={0: column_name, 1: 'unit'})
        size_info[column_name] = size_info[column_name].replace('', np.nan).astype(float) # dtypeがobjectになってるのでfloatに直す
        size_info[column_name] = size_info.apply(lambda row: row[column_name] * 10 if row['unit'] == 'cm' else row[column_name], axis=1) # 単位をmmに統一する
        output_df[column_name] = size_info[column_name]

    return output_df


class SubtitleSizeBlock(BaseBlock):
    '''sub_titleから作品のサイズ(W,H,t,D)/面積/アスペクト比/欠損している属性数を抽出する
    '''
    def transform(self, input_df: pd.DataFrame):
        output_df = detect_size_from_subtitle(input_df)
        output_df["area"] = output_df["size_w"] * output_df["size_h"]
        output_df["aspect"] = output_df["size_w"] / output_df["size_h"]
        output_df["missing_attributes"] = output_df.isnull().sum(axis=1)

        return output_df.add_prefix("Subtitle_")


def parse_year(s: str):
    """maker data の date of birth / death を parse する method"""
    if s is None:
        return None

    if isinstance(s, float):
        return s

    if '-' not in s:
        return int(s)

    return int(s.split('-')[0])


class MakerAgeBlock(BaseBlock):
    '''principal_makerの生まれた年/亡くなった年や制作開始/終了時点での年齢
    '''
    def fit(self, input_df: pd.DataFrame, y=None):
        maker_df = art_ds.maker_df
        output_df = maker_df[["name"]].copy()

        output_df["birth_year"] = maker_df["date_of_birth"].map(parse_year)
        output_df["death_year"] = maker_df["date_of_death"].map(parse_year)
        output_df["living_year"] = output_df["death_year"] - output_df["birth_year"]
        self.agg_df = output_df

        return self.transform(input_df)

    def transform(self, input_df: pd.DataFrame):
        output_df = merge_by_key(input_df["principal_maker"].rename("name"), self.agg_df, on="name")
        output_df["age_in_dationg_early"] = input_df["dating_year_early"] - output_df["birth_year"]
        output_df["age_in_dationg_late"] = input_df["dating_year_late"] - output_df["birth_year"]

        return output_df.add_prefix("principal_maker_")


class ObjectYearMetaBlock(BaseBlock):
    '''objectの制作開始/終了/期間などに関する特徴
    '''
    def transform(self, input_df: pd.DataFrame):
        output_df = pd.DataFrame()

        output_df["acquisition_year"] = pd.to_datetime(input_df["acquisition_date"]).dt.year
        output_df["dating_sorting_date"] = input_df["dating_sorting_date"]
        output_df["dating_period"] = input_df["dating_period"]
        output_df["dating_year_early"] = input_df["dating_year_early"]
        output_df["dating_year_late"] = input_df["dating_year_late"]
        output_df["diff_dating_year"] = output_df["dating_year_late"] - output_df["dating_year_early"]
        output_df["diff_acquisition_dating"] = output_df["acquisition_year"] - output_df["dating_year_late"]

        return output_df


class PrincipalMakerCountByObjectBlock(BaseBlock):
    '''object_id単位でのprincipal makerのcrosstab集計
    '''
    def fit(self, input_df: pd.DataFrame, y=None):
        maker_df = art_ds.principal_maker_df
        agg_df = pd.DataFrame()

        for col in ["qualification", "roles", "productionPlaces"]:
            _df = pd.crosstab(maker_df["object_id"], maker_df[col])

            agg_df = pd.concat([_df.add_prefix(f"{col}_"), agg_df], axis=1)

        self.agg_df = agg_df

        return self.transform(input_df)

    def transform(self, input_df: pd.DataFrame):
        output_df = merge_by_key(input_df, self.agg_df).fillna(0).astype(int)

        return output_df.add_prefix("PrincipalMakerByObject_")


class PrincipalMakerCountByMakerBlock(BaseBlock):
    '''principal_maker単位でのprincipal makerのcrosstab集計
    '''
    def fit(self, input_df: pd.DataFrame, y=None):
        maker_df = art_ds.principal_maker_df
        agg_df = pd.DataFrame()

        for col in ["qualification", "roles", "productionPlaces"]:
            _df = pd.crosstab(maker_df["maker_name"], maker_df[col])

            agg_df = pd.concat([_df.add_prefix(f"{col}_"), agg_df], axis=1)

        agg_df.index = agg_df.index.rename("principal_maker")
        self.agg_df = agg_df

        return self.transform(input_df)

    def transform(self, input_df: pd.DataFrame):
        output_df = merge_by_key(input_df, self.agg_df, on="principal_maker").fillna(0).astype(int)

        return output_df.add_prefix("PrincipalMakerByMaker_")

# %% [markdown]
# ## Text feature

# %%
class StringLengthBlock(BaseBlock):
    '''文字列の長さを返す
    '''
    def __init__(self, columns: list):
        self.columns = columns

    def transform(self, input_df: pd.DataFrame):
        output_df = pd.DataFrame()
        for col in self.columns:
            output_df[col] = input_df[col].fillna("").str.len()

        return output_df.add_prefix("StringLength_")


class WordCountBlock(BaseBlock):
    '''train/testの単語数をカウント
    '''
    def __init__(self, columns: list):
        self.columns = columns

    def transform(self, input_df: pd.DataFrame):
        output_df = pd.DataFrame()
        for col in self.columns:
            output_df[col] = input_df[col].fillna("").apply(lambda x: len(x.split()))

        return output_df.add_prefix("WordCount_")

    
def text_normalization(text):
    '''textheroを用いたテキスト前処理pipeline
    '''
    # nltkのオランダ語と英語のstopword
    custom_stopwords = nltk.corpus.stopwords.words('dutch') + nltk.corpus.stopwords.words('english')

    clean_text = hero.clean(
        text, 
        pipeline=[
            hero.preprocessing.fillna,
            hero.preprocessing.lowercase,
            hero.preprocessing.remove_digits,
            hero.preprocessing.remove_punctuation,
            hero.preprocessing.remove_diacritics,
            lambda x: hero.preprocessing.remove_stopwords(x, stopwords=custom_stopwords),
            hero.preprocessing.remove_whitespace,
        ])

    return clean_text


class TfidfBlock(BaseBlock):
    '''TF-IDF特徴量
    - 複数カラムに対応
    '''
    def __init__(self, column: str, n_components: int = 50):
        self.column = column
        self.n_components = n_components

    def get_text_series(self, input_df: pd.DataFrame) -> pd.Series:
        '''input_dfを入力としてテキスト正規化したpd.Seriesを返す
        &で連結された複数カラムの場合は空白区切りでテキストを連結させる
        '''
        out_series = None

        for i, col in enumerate(self.column.split('&')):
            text_i = text_normalization(input_df[col]).astype(str)
            if out_series is None:
                out_series = text_i
            else:
                out_series = out_series + ' ' + text_i

        return out_series

    def fit(self, input_df: pd.DataFrame, y=None):
        whole_df = art_ds.get_whole_df()
        x = self.get_text_series(whole_df)

        self.pipeline = Pipeline([
            ('tfidf', TfidfVectorizer(max_features=20000)),
            ('svd', TruncatedSVD(n_components=self.n_components, random_state=42)),
        ])

        feature = self.pipeline.fit_transform(x)
        self.agg_df = pd.concat([whole_df[[OBJECT_ID]].copy(), pd.DataFrame(feature)], axis=1)

        return self.transform(input_df)

    def transform(self, input_df: pd.DataFrame):
        return merge_by_key(input_df, self.agg_df).add_prefix(f"{self.column}_Tfidf_")


def get_w2v_input_df():
    '''w2vのinputのdataframeを作成する
    - object_idをPKとするdataframeを返すことを想定
    '''
    # whole_df(train/test)
    whole_df = art_ds.get_whole_df()
    whole_df["title"] = whole_df["title"].astype(str)
    whole_df["description"] = whole_df["description"].astype(str)
    whole_df["more_title"] = whole_df["more_title"].astype(str)
    whole_df["title-description"] = whole_df["title"].astype(str) + ' ' + whole_df["description"].astype(str)

    w2v_whole_title = whole_df.groupby(["object_id"])["title"].apply(list).reset_index()
    w2v_whole_description = whole_df.groupby(["object_id"])["description"].apply(list).reset_index()
    w2v_whole_more_title = whole_df.groupby(["object_id"])["more_title"].apply(list).reset_index()
    w2v_whole_title_description = whole_df.groupby(["object_id"])["title-description"].apply(list).reset_index()
    
    # material
    material_df = art_ds.material_df.copy()
    w2v_material = material_df.groupby(["object_id"])["name"].apply(list).reset_index()

    # object
    object_df = art_ds.object_df.copy()
    w2v_object = object_df.groupby(["object_id"])["name"].apply(list).reset_index()

    # technique
    technique_df = art_ds.technique_df.copy()
    w2v_technique = technique_df.groupby(["object_id"])["name"].apply(list).reset_index()

    # material/object
    material_object_df = pd.concat([material_df, object_df], axis=0).reset_index(drop=True)
    w2v_material_object = material_object_df.groupby(["object_id"])["name"].apply(list).reset_index()

    # material/technique
    material_technique_df = pd.concat([material_df, technique_df], axis=0).reset_index(drop=True)
    w2v_material_technique = material_technique_df.groupby(["object_id"])["name"].apply(list).reset_index()

    # object/technique
    object_technique_df = pd.concat([object_df, technique_df], axis=0).reset_index(drop=True)
    w2v_object_technique = object_technique_df.groupby(["object_id"])["name"].apply(list).reset_index()

    # material/object/technique
    material_object_technique_df = pd.concat([material_df, object_df, technique_df], axis=0).reset_index(drop=True)
    w2v_material_object_technique = material_object_technique_df.groupby(["object_id"])["name"].apply(list).reset_index()

    # material + title + description + more_title


    returns = {
        "w2v_whole_title": w2v_whole_title,
        "w2v_whole_description": w2v_whole_description,
        "w2v_whole_more_title": w2v_whole_more_title,
        "w2v_whole_title_description": w2v_whole_title_description,
        "w2v_material": w2v_material,
        "w2v_object": w2v_object,
        "w2v_technique": w2v_technique,
        "w2v_material_object": w2v_material_object,
        "w2v_material_technique": w2v_material_technique,
        "w2v_object_technique": w2v_object_technique,
        "w2v_material_object_technique": w2v_material_object_technique,
    }

    return returns


class W2vBlock(BaseBlock):
    '''Word2Vecによる単語ベクトル表現を得て、平均により文章ベクトル化
    - 単一dataframeで複数カラムに対応
    '''
    def __init__(self, sentences_df: pd.DataFrame, df_name: str, vector_size: int, min_count: int, window: int, epochs: int):
        self.sentences_df = sentences_df
        self.df_name = df_name
        self.vector_size = vector_size
        self.min_count = min_count
        self.window = window
        self.epochs = epochs

    def fit(self, input_df: pd.DataFrame, y=None):
        self.agg_df = art_ds.get_whole_df()[['object_id']]
        cat_col = self.sentences_df.columns.drop("object_id")[0]
        # text normalization
        self.sentences_df[cat_col] = text_normalization(self.sentences_df[cat_col])

        self.w2v_model = word2vec.Word2Vec(
            self.sentences_df[cat_col].values.tolist(),
            vector_size=self.vector_size,
            min_count=self.min_count,
            window=self.window,
            epochs=self.epochs,
            sg=1,
        )

        # element-wise average(SWEM-aver)
        sentence_vectors = self.sentences_df[cat_col].progress_apply(lambda x: np.mean([self.w2v_model.wv[e] for e in x], axis=0))
        sentence_vectors = np.vstack(sentence_vectors)
        sentence_vectors_df = pd.DataFrame(sentence_vectors, columns=[f"{self.df_name}_{i}" for i in range(self.vector_size)])
        sentence_vectors_df.index = self.sentences_df["object_id"]
        self.agg_df = self.agg_df.merge(sentence_vectors_df, on='object_id', how='left')
        
        return self.transform(input_df)

    def transform(self, input_df: pd.DataFrame):
        return merge_by_key(input_df, self.agg_df)

# %% [markdown]
# ## palette feature

# %% [markdown]
# ## create feature

# %%
def create_feature(train_df: pd.DataFrame, test_df: pd.DataFrame, y, blocks: list) -> Tuple[pd.DataFrame, pd.DataFrame]:
    train_feat_df = pd.DataFrame()
    test_feat_df = pd.DataFrame()

    for block in blocks:
        with utils.timer(name=f"{str(block) + '_fit'}", logger=logger):
            try:
                out_train_block = block.fit(train_df, y=y)
            except Exception as e:
                print(f'Error on {block} fit. ')
                raise e from e

            assert len(out_train_block) == len(train_df), block

        train_feat_df = pd.concat([train_feat_df, out_train_block], axis=1)

    for block in blocks:
        with utils.timer(name=f"{str(block) + '_transform'}", logger=logger):
            out_test_block = block.transform(test_df)
            assert len(out_test_block) == len(test_df), block

        test_feat_df = pd.concat([test_feat_df, out_test_block], axis=1)

    return train_feat_df, test_feat_df

# %% [markdown]
# ## CV

# %%
def get_group_k_fold(train_df: pd.DataFrame, group_col: str, n_splits: int = 5, seed: int = 42) -> List[tuple]:
    '''GroupKFoldで分割してfold列を付与する
    '''
    _train_df = train_df.copy()
    group_series = _train_df[group_col]
    group_key = group_series.unique()

    splitter = KFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=seed
    )

    fold = []

    for fold_id, (tr_group_idx, val_group_idx) in enumerate(splitter.split(group_key)):
        tr_group = group_key[tr_group_idx]
        val_group = group_key[val_group_idx]

        is_tr = group_series.isin(tr_group)
        is_val = group_series.isin(val_group)

        train_idx = np.array(_train_df[is_tr].index)
        valid_idx = np.array(_train_df[is_val].index)

        fold.append((train_idx, valid_idx))

    return fold


def get_stratified_k_fold(train_df: pd.DataFrame, y: np.ndarray, n_splits: int = 5, seed: int = 42) -> List[tuple]:
    '''StratifiedK-Foldで分割してfold列を付与
    '''
    X_train = train_df.copy()
    y_train = y.round()

    splitter = StratifiedKFold(
        n_splits=n_splits,
        shuffle=True,
        random_state=seed
    )

    fold = []

    for fold_id, (train_idx, valid_idx) in enumerate(splitter.split(X_train, y_train)):
        fold.append((train_idx, valid_idx))

    return fold

# %% [markdown]
# ## models

# %%
class LightGBMTrainer:
    def __init__(
        self,
        X_train: pd.DataFrame,
        y_train: pd.DataFrame,
        X_test: pd.DataFrame,
        params: dict,
        cv: List[tuple],
        seeds: list,
    ):
        self.X_train = X_train
        self.y_train = y_train
        self.X_test = X_test
        self.params = params
        self.cv = cv
        self.seeds = seeds
        self.models = []

    def fit(self):
        oof = np.zeros((len(self.seeds), len(self.y_train)))

        for i, seed in enumerate(self.seeds):
            oof_ = np.zeros((len(self.y_train)))
            self.params["seed"] = seed

            for train_idx, valid_idx in self.cv:
                X_train_fold = self.X_train.iloc[train_idx].values
                X_valid_fold = self.X_train.iloc[valid_idx].values

                y_train_fold = self.y_train[train_idx]
                y_valid_fold = self.y_train[valid_idx]

                train_set = lgb.Dataset(X_train_fold, y_train_fold)
                valid_set = lgb.Dataset(X_valid_fold, y_valid_fold, reference=train_set)

                model = lgb.train(
                    train_set=train_set,
                    valid_sets=[train_set, valid_set],
                    params=self.params,
                    verbose_eval=100,
                    # callbacks=[wandb_callback()]
                )

                oof_[valid_idx] = model.predict(
                    X_valid_fold,
                    num_iteration=model.best_iteration,
                )
                
                self.models.append(model)

            oof[i, :] = oof_
        
        y_oof = np.mean(oof, axis=0)

        return y_oof, self.models

    def predict(self):
        y_pred = np.mean(
            [model.predict(self.X_test) for model in self.models], axis=0
        )

        return y_pred

# %% [markdown]
# ## Training / Inference

# %%
# config
lgb_params = {
    "objective": "regression",
    "metric": "rmse",
    "boosting_type": "gbdt",
    "learning_rate": 0.01,
    "max_depth": 5,
    "num_leaves": 32,
    "lambda_l1": 0.01,
    "lambda_l2": 0.01,
    "bagging_fraction": 0.9,
    "bagging_freq": 3,
    "feature_fraction": 0.9,
    "min_data_in_leaf": 20,
    "num_threads": 8,
    "verbosity": -1,
    "num_iterations": 10000,
    "early_stopping_round": 100,
}
# wandb.config.update(lgb_params)
seeds = [42, 2021, 2434, 1123, 98]

# feature engineering
train_df = art_ds.train_df
test_df = art_ds.test_df
y_train = art_ds.get_target(log=True)
cv = get_stratified_k_fold(train_df, y_train, 5, 42)

blocks = [
    # table/aggregate features
    OrdinalEncodingBlock(
        cat_cols=[
            "principal_maker",
            "principal_or_first_maker",
            "copyright_holder",
            "acquisition_method",
        ]
    ),
    CountEncodingBlock(
        cat_cols=[
            "principal_maker",
            "principal_or_first_maker",
            "acquisition_method",
        ]
    ),
    TargetEncodingBlock(
        columns=["principal_maker"],
        target_column="likes",
        cv=cv,
    ),
    *[OtherTableCountBlock(
    category_df=df,
    df_name=name,
    minimum_freq=30
    )
    for df, name in zip(
        [art_ds.material_df, art_ds.technique_df, art_ds.production_df, art_ds.historical_df],
        ["material", "technique", "production_place", "historical_person"])
    ],
    SubtitleSizeBlock(),
    MakerAgeBlock(),
    ObjectYearMetaBlock(),
    PrincipalMakerCountByObjectBlock(),
    PrincipalMakerCountByMakerBlock(),
    # text feature
    StringLengthBlock(
        columns=[
            'title',
            'description',
            'long_title',
            'more_title',
            'sub_title',
        ]
    ),
    WordCountBlock(
        columns=[
            'title',
            'description',
            'long_title',
            'more_title',
            'sub_title',
        ]
    ),
    *[TfidfBlock(
        column=column,
        n_components=50) for column in [
            "title",
            "description",
            "long_title",
            "more_title",
            "title&description&long_title&more_title",
            "acquisition_credit_line",
        ]
    ],
    *[W2vBlock(
        sentences_df=sentences_df,
        df_name=df_name,
        vector_size=50,
        min_count=1,
        window=5,
        epochs=100
        ) for df_name, sentences_df in get_w2v_input_df().items()
    ],
]

# training/inference
X_train, X_test = create_feature(train_df, test_df, y_train, blocks)

trainer = LightGBMTrainer(X_train, y_train, X_test, lgb_params, cv, seeds)
y_oof, models = trainer.fit()
y_pred = trainer.predict()
# Out:
# [2021-04-04 23:56:55,923] [INFO] [<<__main__.OrdinalEncodingBlock object at 0x1458e4f10>_fit> start]
# [2021-04-04 23:56:55,963] [INFO] [<<__main__.OrdinalEncodingBlock object at 0x1458e4f10>_fit> done in 0.04 s]
# [2021-04-04 23:56:55,965] [INFO] [<<__main__.CountEncodingBlock object at 0x143296d00>_fit> start]
# [2021-04-04 23:56:55,996] [INFO] [<<__main__.CountEncodingBlock object at 0x143296d00>_fit> done in 0.03 s]
# [2021-04-04 23:56:55,999] [INFO] [<<__main__.TargetEncodingBlock object at 0x143296790>_fit> start]
# [2021-04-04 23:56:56,062] [INFO] [<<__main__.TargetEncodingBlock object at 0x143296790>_fit> done in 0.06 s]
# [2021-04-04 23:56:56,064] [INFO] [<<__main__.OtherTableCountBlock object at 0x143296250>_fit> start]
# [2021-04-04 23:56:56,440] [INFO] [<<__main__.OtherTableCountBlock object at 0x143296250>_fit> done in 0.38 s]
# [2021-04-04 23:56:56,442] [INFO] [<<__main__.OtherTableCountBlock object at 0x13aac74c0>_fit> start]
# [2021-04-04 23:56:56,671] [INFO] [<<__main__.OtherTableCountBlock object at 0x13aac74c0>_fit> done in 0.23 s]
# [2021-04-04 23:56:56,675] [INFO] [<<__main__.OtherTableCountBlock object at 0x13aac7dc0>_fit> start]
# [2021-04-04 23:56:56,911] [INFO] [<<__main__.OtherTableCountBlock object at 0x13aac7dc0>_fit> done in 0.24 s]
# [2021-04-04 23:56:56,917] [INFO] [<<__main__.OtherTableCountBlock object at 0x13aac72e0>_fit> start]
# [2021-04-04 23:56:56,978] [INFO] [<<__main__.OtherTableCountBlock object at 0x13aac72e0>_fit> done in 0.06 s]
# [2021-04-04 23:56:56,986] [INFO] [<<__main__.SubtitleSizeBlock object at 0x143296490>_fit> start]
# [2021-04-04 23:56:57,580] [INFO] [<<__main__.SubtitleSizeBlock object at 0x143296490>_fit> done in 0.59 s]
# [2021-04-04 23:56:57,591] [INFO] [<<__main__.MakerAgeBlock object at 0x143296a30>_fit> start]
# [2021-04-04 23:56:57,605] [INFO] [<<__main__.MakerAgeBlock object at 0x143296a30>_fit> done in 0.01 s]
# [2021-04-04 23:56:57,615] [INFO] [<<__main__.ObjectYearMetaBlock object at 0x13aac7520>_fit> start]
# [2021-04-04 23:56:57,625] [INFO] [<<__main__.ObjectYearMetaBlock object at 0x13aac7520>_fit> done in 0.01 s]
# [2021-04-04 23:56:57,637] [INFO] [<<__main__.PrincipalMakerCountByObjectBlock object at 0x13aac7df0>_fit> start]
# [2021-04-04 23:56:58,195] [INFO] [<<__main__.PrincipalMakerCountByObjectBlock object at 0x13aac7df0>_fit> done in 0.56 s]
# [2021-04-04 23:56:58,210] [INFO] [<<__main__.PrincipalMakerCountByMakerBlock object at 0x13aac7c10>_fit> start]
# [2021-04-04 23:56:58,371] [INFO] [<<__main__.PrincipalMakerCountByMakerBlock object at 0x13aac7c10>_fit> done in 0.16 s]
# [2021-04-04 23:56:58,389] [INFO] [<<__main__.StringLengthBlock object at 0x13aac7ee0>_fit> start]
# [2021-04-04 23:56:58,422] [INFO] [<<__main__.StringLengthBlock object at 0x13aac7ee0>_fit> done in 0.03 s]
# [2021-04-04 23:56:58,445] [INFO] [<<__main__.WordCountBlock object at 0x13aac79a0>_fit> start]
# [2021-04-04 23:56:58,505] [INFO] [<<__main__.WordCountBlock object at 0x13aac79a0>_fit> done in 0.06 s]
# [2021-04-04 23:56:58,529] [INFO] [<<__main__.TfidfBlock object at 0x13aac7e50>_fit> start]
# /Users/azupero/data-science/atmaCup/atmaCup-10/.venv/lib/python3.8/site-packages/texthero/preprocessing.py:64: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# /Users/azupero/data-science/atmaCup/atmaCup-10/.venv/lib/python3.8/site-packages/texthero/preprocessing.py:123: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# [2021-04-04 23:57:00,226] [INFO] [<<__main__.TfidfBlock object at 0x13aac7e50>_fit> done in 1.70 s]
# [2021-04-04 23:57:00,253] [INFO] [<<__main__.TfidfBlock object at 0x13aac7670>_fit> start]
# [2021-04-04 23:57:04,622] [INFO] [<<__main__.TfidfBlock object at 0x13aac7670>_fit> done in 4.37 s]
# [2021-04-04 23:57:04,657] [INFO] [<<__main__.TfidfBlock object at 0x13aac7a90>_fit> start]
# [2021-04-04 23:57:06,973] [INFO] [<<__main__.TfidfBlock object at 0x13aac7a90>_fit> done in 2.32 s]
# [2021-04-04 23:57:07,008] [INFO] [<<__main__.TfidfBlock object at 0x13aac7b20>_fit> start]
# [2021-04-04 23:57:09,337] [INFO] [<<__main__.TfidfBlock object at 0x13aac7b20>_fit> done in 2.33 s]
# [2021-04-04 23:57:09,376] [INFO] [<<__main__.TfidfBlock object at 0x13aac7c70>_fit> start]
# [2021-04-04 23:57:18,486] [INFO] [<<__main__.TfidfBlock object at 0x13aac7c70>_fit> done in 9.11 s]
# [2021-04-04 23:57:18,528] [INFO] [<<__main__.TfidfBlock object at 0x13aac7190>_fit> start]
# [2021-04-04 23:57:19,287] [INFO] [<<__main__.TfidfBlock object at 0x13aac7190>_fit> done in 0.76 s]
# [2021-04-04 23:57:19,339] [INFO] [<<__main__.W2vBlock object at 0x13aac7a60>_fit> start]
# [2021-04-04 23:57:20,621] [INFO] [collecting all words and their counts]
# [2021-04-04 23:57:20,622] [WARNING] [Each 'sentences' item should be a list of words (usually unicode strings). First item here is instead plain <class 'str'>.]
# [2021-04-04 23:57:20,622] [INFO] [PROGRESS: at sentence #0, processed 0 words, keeping 0 word types]
# [2021-04-04 23:57:20,647] [INFO] [PROGRESS: at sentence #10000, processed 331962 words, keeping 39 word types]
# [2021-04-04 23:57:20,674] [INFO] [PROGRESS: at sentence #20000, processed 664156 words, keeping 39 word types]
# [2021-04-04 23:57:20,686] [INFO] [collected 39 word types from a corpus of 797406 raw words and 24034 sentences]
# [2021-04-04 23:57:20,687] [INFO] [Creating a fresh vocabulary]
# [2021-04-04 23:57:20,687] [INFO] [Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 39 unique words (100.0%% of original 39, drops 0)', 'datetime': '2021-04-04T23:57:20.687921', 'gensim': '4.0.1', 'python': '3.8.8 (default, Mar 26 2021, 12:58:44) \n[Clang 12.0.0 (clang-1200.0.32.29)]', 'platform': 'macOS-10.15.7-x86_64-i386-64bit', 'event': 'prepare_vocab'}]
# [2021-04-04 23:57:20,688] [INFO] [Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 797406 word corpus (100.0%% of original 797406, drops 0)', 'datetime': '2021-04-04T23:57:20.688825', 'gensim': '4.0.1', 'python': '3.8.8 (default, Mar 26 2021, 12:58:44) \n[Clang 12.0.0 (clang-1200.0.32.29)]', 'platform': 'macOS-10.15.7-x86_64-i386-64bit', 'event': 'prepare_vocab'}]
# [2021-04-04 23:57:20,689] [INFO] [deleting the raw counts dictionary of 39 items]
# [2021-04-04 23:57:20,690] [INFO] [sample=0.001 downsamples 25 most-common words]
# [2021-04-04 23:57:20,690] [INFO] [Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 138110.07154260323 word corpus (17.3%% of prior 797406)', 'datetime': '2021-04-04T23:57:20.690950', 'gensim': '4.0.1', 'python': '3.8.8 (default, Mar 26 2021, 12:58:44) \n[Clang 12.0.0 (clang-1200.0.32.29)]', 'platform': 'macOS-10.15.7-x86_64-i386-64bit', 'event': 'prepare_vocab'}]
# [2021-04-04 23:57:20,692] [INFO] [estimated required memory for 39 words and 50 dimensions: 35100 bytes]
# [2021-04-04 23:57:20,692] [INFO] [resetting layer weights]
# [2021-04-04 23:57:20,693] [INFO] [Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2021-04-04T23:57:20.693686', 'gensim': '4.0.1', 'python': '3.8.8 (default, Mar 26 2021, 12:58:44) \n[Clang 12.0.0 (clang-1200.0.32.29)]', 'platform': 'macOS-10.15.7-x86_64-i386-64bit', 'event': 'build_vocab'}]
# [2021-04-04 23:57:20,694] [INFO] [Word2Vec lifecycle event {'msg': 'training model with 3 workers on 39 vocabulary and 50 features, using sg=1 hs=0 sample=0.001 negative=5 window=5', 'datetime': '2021-04-04T23:57:20.694321', 'gensim': '4.0.1', 'python': '3.8.8 (default, Mar 26 2021, 12:58:44) \n[Clang 12.0.0 (clang-1200.0.32.29)]', 'platform': 'macOS-10.15.7-x86_64-i386-64bit', 'event': 'train'}]
# [2021-04-04 23:57:20,861] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:20,864] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:20,865] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:20,865] [INFO] [EPOCH - 1 : training on 797406 raw words (137722 effective words) took 0.2s, 825743 effective words/s]
# [2021-04-04 23:57:21,031] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:21,034] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:21,035] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:21,035] [INFO] [EPOCH - 2 : training on 797406 raw words (138421 effective words) took 0.2s, 840239 effective words/s]
# [2021-04-04 23:57:21,204] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:21,205] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:21,207] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:21,208] [INFO] [EPOCH - 3 : training on 797406 raw words (138588 effective words) took 0.2s, 828577 effective words/s]
# [2021-04-04 23:57:21,372] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:21,373] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:21,375] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:21,375] [INFO] [EPOCH - 4 : training on 797406 raw words (138499 effective words) took 0.2s, 852771 effective words/s]
# [2021-04-04 23:57:21,595] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:21,596] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:21,599] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:21,600] [INFO] [EPOCH - 5 : training on 797406 raw words (138892 effective words) took 0.2s, 631046 effective words/s]
# [2021-04-04 23:57:21,844] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:21,848] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:21,849] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:21,850] [INFO] [EPOCH - 6 : training on 797406 raw words (137812 effective words) took 0.2s, 564519 effective words/s]
# [2021-04-04 23:57:22,015] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:22,018] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:22,020] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:22,020] [INFO] [EPOCH - 7 : training on 797406 raw words (137840 effective words) took 0.2s, 831577 effective words/s]
# [2021-04-04 23:57:22,189] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:22,190] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:22,192] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:22,193] [INFO] [EPOCH - 8 : training on 797406 raw words (138316 effective words) took 0.2s, 834346 effective words/s]
# [2021-04-04 23:57:22,357] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:22,359] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:22,359] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:22,360] [INFO] [EPOCH - 9 : training on 797406 raw words (137866 effective words) took 0.2s, 854303 effective words/s]
# [2021-04-04 23:57:22,530] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:22,532] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:22,533] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:22,534] [INFO] [EPOCH - 10 : training on 797406 raw words (138114 effective words) took 0.2s, 816950 effective words/s]
# [2021-04-04 23:57:22,701] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:22,703] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:22,703] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:22,704] [INFO] [EPOCH - 11 : training on 797406 raw words (138050 effective words) took 0.2s, 849492 effective words/s]
# [2021-04-04 23:57:22,872] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:22,874] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:22,874] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:22,875] [INFO] [EPOCH - 12 : training on 797406 raw words (137995 effective words) took 0.2s, 830851 effective words/s]
# [2021-04-04 23:57:23,043] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:23,046] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:23,047] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:23,047] [INFO] [EPOCH - 13 : training on 797406 raw words (138105 effective words) took 0.2s, 841163 effective words/s]
# [2021-04-04 23:57:23,213] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:23,215] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:23,217] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:23,217] [INFO] [EPOCH - 14 : training on 797406 raw words (137535 effective words) took 0.2s, 833304 effective words/s]
# [2021-04-04 23:57:23,384] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:23,387] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:23,388] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:23,389] [INFO] [EPOCH - 15 : training on 797406 raw words (137810 effective words) took 0.2s, 827359 effective words/s]
# [2021-04-04 23:57:23,551] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:23,554] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:23,556] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:23,556] [INFO] [EPOCH - 16 : training on 797406 raw words (137510 effective words) took 0.2s, 864257 effective words/s]
# [2021-04-04 23:57:23,719] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:23,721] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:23,721] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:23,722] [INFO] [EPOCH - 17 : training on 797406 raw words (137527 effective words) took 0.2s, 846928 effective words/s]
# [2021-04-04 23:57:23,885] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:23,888] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:23,889] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:23,890] [INFO] [EPOCH - 18 : training on 797406 raw words (137774 effective words) took 0.2s, 847863 effective words/s]
# [2021-04-04 23:57:24,055] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:24,056] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:24,058] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:24,059] [INFO] [EPOCH - 19 : training on 797406 raw words (138333 effective words) took 0.2s, 849089 effective words/s]
# [2021-04-04 23:57:24,224] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:24,225] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:24,226] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:24,226] [INFO] [EPOCH - 20 : training on 797406 raw words (137870 effective words) took 0.2s, 844920 effective words/s]
# [2021-04-04 23:57:24,391] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:24,394] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:24,395] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:24,396] [INFO] [EPOCH - 21 : training on 797406 raw words (138115 effective words) took 0.2s, 842382 effective words/s]
# [2021-04-04 23:57:24,562] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:24,564] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:24,566] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:24,567] [INFO] [EPOCH - 22 : training on 797406 raw words (138489 effective words) took 0.2s, 832652 effective words/s]
# [2021-04-04 23:57:24,732] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:24,735] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:24,735] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:24,736] [INFO] [EPOCH - 23 : training on 797406 raw words (138096 effective words) took 0.2s, 840907 effective words/s]
# [2021-04-04 23:57:24,902] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:24,904] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:24,905] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:24,906] [INFO] [EPOCH - 24 : training on 797406 raw words (138366 effective words) took 0.2s, 839750 effective words/s]
# [2021-04-04 23:57:25,072] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:25,075] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:25,076] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:25,077] [INFO] [EPOCH - 25 : training on 797406 raw words (138448 effective words) took 0.2s, 832201 effective words/s]
# [2021-04-04 23:57:25,240] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:25,242] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:25,243] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:25,244] [INFO] [EPOCH - 26 : training on 797406 raw words (137581 effective words) took 0.2s, 847521 effective words/s]
# [2021-04-04 23:57:25,409] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:25,412] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:25,413] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:25,414] [INFO] [EPOCH - 27 : training on 797406 raw words (138091 effective words) took 0.2s, 834043 effective words/s]
# [2021-04-04 23:57:25,584] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:25,587] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:25,588] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:25,588] [INFO] [EPOCH - 28 : training on 797406 raw words (138529 effective words) took 0.2s, 817308 effective words/s]
# [2021-04-04 23:57:25,754] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:25,755] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:25,756] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:25,757] [INFO] [EPOCH - 29 : training on 797406 raw words (137807 effective words) took 0.2s, 841495 effective words/s]
# [2021-04-04 23:57:25,920] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:25,923] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:25,924] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:25,925] [INFO] [EPOCH - 30 : training on 797406 raw words (138175 effective words) took 0.2s, 852001 effective words/s]
# [2021-04-04 23:57:26,091] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:26,094] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:26,095] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:26,095] [INFO] [EPOCH - 31 : training on 797406 raw words (137986 effective words) took 0.2s, 833942 effective words/s]
# [2021-04-04 23:57:26,265] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:26,267] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:26,268] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:26,269] [INFO] [EPOCH - 32 : training on 797406 raw words (137955 effective words) took 0.2s, 819315 effective words/s]
# [2021-04-04 23:57:26,438] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:26,441] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:26,441] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:26,442] [INFO] [EPOCH - 33 : training on 797406 raw words (137859 effective words) took 0.2s, 819457 effective words/s]
# [2021-04-04 23:57:26,609] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:26,610] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:26,612] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:26,612] [INFO] [EPOCH - 34 : training on 797406 raw words (138379 effective words) took 0.2s, 838183 effective words/s]
# [2021-04-04 23:57:26,777] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:26,780] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:26,781] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:26,782] [INFO] [EPOCH - 35 : training on 797406 raw words (138138 effective words) took 0.2s, 832524 effective words/s]
# [2021-04-04 23:57:26,947] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:26,948] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:26,948] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:26,949] [INFO] [EPOCH - 36 : training on 797406 raw words (138033 effective words) took 0.2s, 850303 effective words/s]
# [2021-04-04 23:57:27,115] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:27,117] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:27,118] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:27,119] [INFO] [EPOCH - 37 : training on 797406 raw words (137705 effective words) took 0.2s, 835141 effective words/s]
# [2021-04-04 23:57:27,280] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:27,283] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:27,284] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:27,285] [INFO] [EPOCH - 38 : training on 797406 raw words (138208 effective words) took 0.2s, 864353 effective words/s]
# [2021-04-04 23:57:27,449] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:27,452] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:27,453] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:27,453] [INFO] [EPOCH - 39 : training on 797406 raw words (137976 effective words) took 0.2s, 841828 effective words/s]
# [2021-04-04 23:57:27,635] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:27,635] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:27,637] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:27,637] [INFO] [EPOCH - 40 : training on 797406 raw words (137926 effective words) took 0.2s, 772880 effective words/s]
# [2021-04-04 23:57:27,801] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:27,802] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:27,804] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:27,804] [INFO] [EPOCH - 41 : training on 797406 raw words (137358 effective words) took 0.2s, 847010 effective words/s]
# [2021-04-04 23:57:27,969] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:27,970] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:27,970] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:27,971] [INFO] [EPOCH - 42 : training on 797406 raw words (138551 effective words) took 0.2s, 850117 effective words/s]
# [2021-04-04 23:57:28,139] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:28,140] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:28,141] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:28,142] [INFO] [EPOCH - 43 : training on 797406 raw words (137987 effective words) took 0.2s, 833045 effective words/s]
# [2021-04-04 23:57:28,306] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:28,309] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:28,310] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:28,311] [INFO] [EPOCH - 44 : training on 797406 raw words (137562 effective words) took 0.2s, 839409 effective words/s]
# [2021-04-04 23:57:28,474] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:28,475] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:28,476] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:28,477] [INFO] [EPOCH - 45 : training on 797406 raw words (137874 effective words) took 0.2s, 859026 effective words/s]
# [2021-04-04 23:57:28,659] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:28,660] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:28,661] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:28,661] [INFO] [EPOCH - 46 : training on 797406 raw words (138617 effective words) took 0.2s, 771842 effective words/s]
# [2021-04-04 23:57:28,826] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:28,829] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:28,829] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:28,830] [INFO] [EPOCH - 47 : training on 797406 raw words (138038 effective words) took 0.2s, 836648 effective words/s]
# [2021-04-04 23:57:28,996] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:28,997] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:28,999] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:29,000] [INFO] [EPOCH - 48 : training on 797406 raw words (137706 effective words) took 0.2s, 834908 effective words/s]
# [2021-04-04 23:57:29,166] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:29,168] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:29,169] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:29,170] [INFO] [EPOCH - 49 : training on 797406 raw words (138027 effective words) took 0.2s, 836327 effective words/s]
# [2021-04-04 23:57:29,350] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:29,352] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:29,353] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:29,353] [INFO] [EPOCH - 50 : training on 797406 raw words (137913 effective words) took 0.2s, 773464 effective words/s]
# [2021-04-04 23:57:29,518] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:29,521] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:29,522] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:29,522] [INFO] [EPOCH - 51 : training on 797406 raw words (138665 effective words) took 0.2s, 842538 effective words/s]
# [2021-04-04 23:57:29,689] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:29,691] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:29,692] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:29,692] [INFO] [EPOCH - 52 : training on 797406 raw words (138062 effective words) took 0.2s, 839867 effective words/s]
# [2021-04-04 23:57:29,874] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:29,875] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:29,876] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:29,876] [INFO] [EPOCH - 53 : training on 797406 raw words (138274 effective words) took 0.2s, 772498 effective words/s]
# [2021-04-04 23:57:30,051] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:30,052] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:30,052] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:30,053] [INFO] [EPOCH - 54 : training on 797406 raw words (138565 effective words) took 0.2s, 808105 effective words/s]
# [2021-04-04 23:57:30,218] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:30,220] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:30,222] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:30,222] [INFO] [EPOCH - 55 : training on 797406 raw words (137792 effective words) took 0.2s, 840441 effective words/s]
# [2021-04-04 23:57:30,387] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:30,388] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:30,390] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:30,391] [INFO] [EPOCH - 56 : training on 797406 raw words (138049 effective words) took 0.2s, 850029 effective words/s]
# [2021-04-04 23:57:30,557] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:30,558] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:30,561] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:30,562] [INFO] [EPOCH - 57 : training on 797406 raw words (137940 effective words) took 0.2s, 827303 effective words/s]
# [2021-04-04 23:57:30,729] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:30,732] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:30,732] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:30,733] [INFO] [EPOCH - 58 : training on 797406 raw words (138044 effective words) took 0.2s, 835178 effective words/s]
# [2021-04-04 23:57:30,902] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:30,904] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:30,905] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:30,906] [INFO] [EPOCH - 59 : training on 797406 raw words (138754 effective words) took 0.2s, 825901 effective words/s]
# [2021-04-04 23:57:31,071] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:31,072] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:31,073] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:31,074] [INFO] [EPOCH - 60 : training on 797406 raw words (138033 effective words) took 0.2s, 847605 effective words/s]
# [2021-04-04 23:57:31,240] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:31,241] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:31,243] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:31,244] [INFO] [EPOCH - 61 : training on 797406 raw words (138651 effective words) took 0.2s, 840828 effective words/s]
# [2021-04-04 23:57:31,409] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:31,412] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:31,413] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:31,413] [INFO] [EPOCH - 62 : training on 797406 raw words (138025 effective words) took 0.2s, 839913 effective words/s]
# [2021-04-04 23:57:31,578] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:31,580] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:31,581] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:31,582] [INFO] [EPOCH - 63 : training on 797406 raw words (138311 effective words) took 0.2s, 848839 effective words/s]
# [2021-04-04 23:57:31,745] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:31,748] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:31,749] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:31,749] [INFO] [EPOCH - 64 : training on 797406 raw words (138012 effective words) took 0.2s, 845647 effective words/s]
# [2021-04-04 23:57:31,915] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:31,917] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:31,918] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:31,919] [INFO] [EPOCH - 65 : training on 797406 raw words (137941 effective words) took 0.2s, 838778 effective words/s]
# [2021-04-04 23:57:32,084] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:32,087] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:32,088] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:32,088] [INFO] [EPOCH - 66 : training on 797406 raw words (138019 effective words) took 0.2s, 837499 effective words/s]
# [2021-04-04 23:57:32,252] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:32,254] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:32,255] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:32,255] [INFO] [EPOCH - 67 : training on 797406 raw words (138477 effective words) took 0.2s, 854203 effective words/s]
# [2021-04-04 23:57:32,423] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:32,426] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:32,427] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:32,428] [INFO] [EPOCH - 68 : training on 797406 raw words (137604 effective words) took 0.2s, 824054 effective words/s]
# [2021-04-04 23:57:32,596] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:32,597] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:32,598] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:32,598] [INFO] [EPOCH - 69 : training on 797406 raw words (138305 effective words) took 0.2s, 832415 effective words/s]
# [2021-04-04 23:57:32,763] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:32,764] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:32,766] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:32,766] [INFO] [EPOCH - 70 : training on 797406 raw words (138138 effective words) took 0.2s, 853197 effective words/s]
# [2021-04-04 23:57:32,935] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:32,936] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:32,937] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:32,937] [INFO] [EPOCH - 71 : training on 797406 raw words (137892 effective words) took 0.2s, 829887 effective words/s]
# [2021-04-04 23:57:33,104] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:33,105] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:33,106] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:33,107] [INFO] [EPOCH - 72 : training on 797406 raw words (138843 effective words) took 0.2s, 841451 effective words/s]
# [2021-04-04 23:57:33,280] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:33,283] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:33,284] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:33,285] [INFO] [EPOCH - 73 : training on 797406 raw words (137843 effective words) took 0.2s, 796639 effective words/s]
# [2021-04-04 23:57:33,452] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:33,454] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:33,455] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:33,455] [INFO] [EPOCH - 74 : training on 797406 raw words (137815 effective words) took 0.2s, 831031 effective words/s]
# [2021-04-04 23:57:33,624] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:33,627] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:33,628] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:33,628] [INFO] [EPOCH - 75 : training on 797406 raw words (138193 effective words) took 0.2s, 825454 effective words/s]
# [2021-04-04 23:57:33,798] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:33,800] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:33,801] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:33,802] [INFO] [EPOCH - 76 : training on 797406 raw words (138100 effective words) took 0.2s, 822379 effective words/s]
# [2021-04-04 23:57:33,969] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:33,970] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:33,971] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:33,972] [INFO] [EPOCH - 77 : training on 797406 raw words (137560 effective words) took 0.2s, 831898 effective words/s]
# [2021-04-04 23:57:34,141] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:34,143] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:34,144] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:34,145] [INFO] [EPOCH - 78 : training on 797406 raw words (138183 effective words) took 0.2s, 824720 effective words/s]
# [2021-04-04 23:57:34,312] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:34,316] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:34,317] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:34,317] [INFO] [EPOCH - 79 : training on 797406 raw words (138079 effective words) took 0.2s, 837905 effective words/s]
# [2021-04-04 23:57:34,486] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:34,488] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:34,489] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:34,490] [INFO] [EPOCH - 80 : training on 797406 raw words (138359 effective words) took 0.2s, 824255 effective words/s]
# [2021-04-04 23:57:34,657] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:34,659] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:34,660] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:34,660] [INFO] [EPOCH - 81 : training on 797406 raw words (138444 effective words) took 0.2s, 836303 effective words/s]
# [2021-04-04 23:57:34,825] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:34,828] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:34,829] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:34,829] [INFO] [EPOCH - 82 : training on 797406 raw words (137677 effective words) took 0.2s, 849202 effective words/s]
# [2021-04-04 23:57:34,994] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:34,995] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:34,996] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:34,997] [INFO] [EPOCH - 83 : training on 797406 raw words (138131 effective words) took 0.2s, 846922 effective words/s]
# [2021-04-04 23:57:35,164] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:35,168] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:35,169] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:35,169] [INFO] [EPOCH - 84 : training on 797406 raw words (138252 effective words) took 0.2s, 825655 effective words/s]
# [2021-04-04 23:57:35,335] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:35,337] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:35,337] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:35,338] [INFO] [EPOCH - 85 : training on 797406 raw words (137829 effective words) took 0.2s, 847955 effective words/s]
# [2021-04-04 23:57:35,507] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:35,508] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:35,509] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:35,510] [INFO] [EPOCH - 86 : training on 797406 raw words (137947 effective words) took 0.2s, 827185 effective words/s]
# [2021-04-04 23:57:35,680] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:35,681] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:35,683] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:35,684] [INFO] [EPOCH - 87 : training on 797406 raw words (138075 effective words) took 0.2s, 821851 effective words/s]
# [2021-04-04 23:57:35,854] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:35,855] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:35,857] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:35,857] [INFO] [EPOCH - 88 : training on 797406 raw words (137757 effective words) took 0.2s, 817550 effective words/s]
# [2021-04-04 23:57:36,023] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:36,025] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:36,026] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:36,027] [INFO] [EPOCH - 89 : training on 797406 raw words (138872 effective words) took 0.2s, 842953 effective words/s]
# [2021-04-04 23:57:36,208] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:36,209] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:36,210] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:36,211] [INFO] [EPOCH - 90 : training on 797406 raw words (138101 effective words) took 0.2s, 774187 effective words/s]
# [2021-04-04 23:57:36,386] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:36,387] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:36,388] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:36,388] [INFO] [EPOCH - 91 : training on 797406 raw words (138696 effective words) took 0.2s, 806595 effective words/s]
# [2021-04-04 23:57:36,555] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:36,556] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:36,557] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:36,558] [INFO] [EPOCH - 92 : training on 797406 raw words (138780 effective words) took 0.2s, 841793 effective words/s]
# [2021-04-04 23:57:36,723] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:36,724] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:36,725] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:36,725] [INFO] [EPOCH - 93 : training on 797406 raw words (137685 effective words) took 0.2s, 852794 effective words/s]
# [2021-04-04 23:57:36,889] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:36,892] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:36,893] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:36,893] [INFO] [EPOCH - 94 : training on 797406 raw words (138222 effective words) took 0.2s, 852676 effective words/s]
# [2021-04-04 23:57:37,060] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:37,062] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:37,063] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:37,063] [INFO] [EPOCH - 95 : training on 797406 raw words (138026 effective words) took 0.2s, 837160 effective words/s]
# [2021-04-04 23:57:37,234] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:37,235] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:37,237] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:37,238] [INFO] [EPOCH - 96 : training on 797406 raw words (138270 effective words) took 0.2s, 815951 effective words/s]
# [2021-04-04 23:57:37,413] [INFO] [worker thread finished; awaiting finish of 2 more threads]
# [2021-04-04 23:57:37,414] [INFO] [worker thread finished; awaiting finish of 1 more threads]
# [2021-04-04 23:57:37,415] [INFO] [worker thread finished; awaiting finish of 0 more threads]
# [2021-04-04 23:57:37,415] [INFO] [EPOCH - 97 : training on 797406 raw words (138526 effective words) took 0.2s, 799105 effective words/s]
# ...
# [600]	training's rmse: 0.864006	valid_1's rmse: 1.01408
# [700]	training's rmse: 0.840654	valid_1's rmse: 1.01038
# [800]	training's rmse: 0.818767	valid_1's rmse: 1.00697
# [900]	training's rmse: 0.799573	valid_1's rmse: 1.00496
# [1000]	training's rmse: 0.780131	valid_1's rmse: 1.00275
# [1100]	training's rmse: 0.763432	valid_1's rmse: 1.00189
# [1200]	training's rmse: 0.74608	valid_1's rmse: 1.00082
# [1300]	training's rmse: 0.729028	valid_1's rmse: 0.999657
# [1400]	training's rmse: 0.712398	valid_1's rmse: 0.998691
# [1500]	training's rmse: 0.697552	valid_1's rmse: 0.997348
# [1600]	training's rmse: 0.681279	valid_1's rmse: 0.996092
# [1700]	training's rmse: 0.666884	valid_1's rmse: 0.995746
# [1800]	training's rmse: 0.651836	valid_1's rmse: 0.995383
# [1900]	training's rmse: 0.6369	valid_1's rmse: 0.994506
# [2000]	training's rmse: 0.623943	valid_1's rmse: 0.993758
# [2100]	training's rmse: 0.611248	valid_1's rmse: 0.993583
# [2200]	training's rmse: 0.598749	valid_1's rmse: 0.993008
# [2300]	training's rmse: 0.585794	valid_1's rmse: 0.992926
# [2400]	training's rmse: 0.574497	valid_1's rmse: 0.993068
# Early stopping, best iteration is:
# [2316]	training's rmse: 0.584183	valid_1's rmse: 0.992805
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.17742	valid_1's rmse: 1.23528
# [200]	training's rmse: 1.01875	valid_1's rmse: 1.12268
# [300]	training's rmse: 0.952099	valid_1's rmse: 1.09396
# [400]	training's rmse: 0.906346	valid_1's rmse: 1.08039
# [500]	training's rmse: 0.875353	valid_1's rmse: 1.07318
# [600]	training's rmse: 0.849515	valid_1's rmse: 1.06786
# [700]	training's rmse: 0.826164	valid_1's rmse: 1.0629
# [800]	training's rmse: 0.805349	valid_1's rmse: 1.05885
# [900]	training's rmse: 0.786718	valid_1's rmse: 1.05609
# [1000]	training's rmse: 0.768371	valid_1's rmse: 1.05386
# [1100]	training's rmse: 0.750869	valid_1's rmse: 1.05163
# [1200]	training's rmse: 0.735921	valid_1's rmse: 1.0503
# [1300]	training's rmse: 0.718105	valid_1's rmse: 1.04855
# [1400]	training's rmse: 0.703928	valid_1's rmse: 1.04758
# [1500]	training's rmse: 0.689633	valid_1's rmse: 1.04671
# [1600]	training's rmse: 0.675057	valid_1's rmse: 1.04573
# [1700]	training's rmse: 0.660944	valid_1's rmse: 1.04545
# [1800]	training's rmse: 0.645576	valid_1's rmse: 1.04449
# [1900]	training's rmse: 0.631958	valid_1's rmse: 1.04352
# [2000]	training's rmse: 0.618624	valid_1's rmse: 1.04305
# [2100]	training's rmse: 0.605524	valid_1's rmse: 1.0424
# [2200]	training's rmse: 0.593104	valid_1's rmse: 1.04158
# [2300]	training's rmse: 0.580951	valid_1's rmse: 1.04112
# [2400]	training's rmse: 0.56948	valid_1's rmse: 1.04117
# Early stopping, best iteration is:
# [2316]	training's rmse: 0.578764	valid_1's rmse: 1.04099
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.18208	valid_1's rmse: 1.22418
# [200]	training's rmse: 1.02134	valid_1's rmse: 1.10151
# [300]	training's rmse: 0.955981	valid_1's rmse: 1.06627
# [400]	training's rmse: 0.915043	valid_1's rmse: 1.05195
# [500]	training's rmse: 0.88505	valid_1's rmse: 1.04346
# [600]	training's rmse: 0.859749	valid_1's rmse: 1.03842
# [700]	training's rmse: 0.836671	valid_1's rmse: 1.03415
# [800]	training's rmse: 0.816835	valid_1's rmse: 1.0309
# [900]	training's rmse: 0.796464	valid_1's rmse: 1.02818
# [1000]	training's rmse: 0.777084	valid_1's rmse: 1.0255
# [1100]	training's rmse: 0.76003	valid_1's rmse: 1.02456
# [1200]	training's rmse: 0.741267	valid_1's rmse: 1.02294
# [1300]	training's rmse: 0.725167	valid_1's rmse: 1.02176
# [1400]	training's rmse: 0.709398	valid_1's rmse: 1.02132
# [1500]	training's rmse: 0.693753	valid_1's rmse: 1.02066
# [1600]	training's rmse: 0.679572	valid_1's rmse: 1.02041
# [1700]	training's rmse: 0.664867	valid_1's rmse: 1.01946
# [1800]	training's rmse: 0.652182	valid_1's rmse: 1.01892
# [1900]	training's rmse: 0.639457	valid_1's rmse: 1.01848
# [2000]	training's rmse: 0.625532	valid_1's rmse: 1.01833
# [2100]	training's rmse: 0.6119	valid_1's rmse: 1.01836
# [2200]	training's rmse: 0.600298	valid_1's rmse: 1.01805
# Early stopping, best iteration is:
# [2167]	training's rmse: 0.603747	valid_1's rmse: 1.01802
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.18273	valid_1's rmse: 1.21998
# [200]	training's rmse: 1.02333	valid_1's rmse: 1.10908
# [300]	training's rmse: 0.958461	valid_1's rmse: 1.08085
# [400]	training's rmse: 0.918988	valid_1's rmse: 1.06796
# [500]	training's rmse: 0.88882	valid_1's rmse: 1.05912
# [600]	training's rmse: 0.863559	valid_1's rmse: 1.05287
# [700]	training's rmse: 0.839601	valid_1's rmse: 1.04738
# [800]	training's rmse: 0.81681	valid_1's rmse: 1.04393
# [900]	training's rmse: 0.797866	valid_1's rmse: 1.04018
# [1000]	training's rmse: 0.77875	valid_1's rmse: 1.03756
# [1100]	training's rmse: 0.759834	valid_1's rmse: 1.03527
# [1200]	training's rmse: 0.743538	valid_1's rmse: 1.0337
# [1300]	training's rmse: 0.726898	valid_1's rmse: 1.03232
# [1400]	training's rmse: 0.710912	valid_1's rmse: 1.03049
# [1500]	training's rmse: 0.694679	valid_1's rmse: 1.02946
# [1600]	training's rmse: 0.681078	valid_1's rmse: 1.02812
# [1700]	training's rmse: 0.665792	valid_1's rmse: 1.02739
# [1800]	training's rmse: 0.650198	valid_1's rmse: 1.02648
# [1900]	training's rmse: 0.634656	valid_1's rmse: 1.02519
# [2000]	training's rmse: 0.619616	valid_1's rmse: 1.02447
# [2100]	training's rmse: 0.606893	valid_1's rmse: 1.02379
# [2200]	training's rmse: 0.593769	valid_1's rmse: 1.02302
# [2300]	training's rmse: 0.581918	valid_1's rmse: 1.02254
# [2400]	training's rmse: 0.570316	valid_1's rmse: 1.02213
# [2500]	training's rmse: 0.558464	valid_1's rmse: 1.02147
# [2600]	training's rmse: 0.546819	valid_1's rmse: 1.02087
# [2700]	training's rmse: 0.536966	valid_1's rmse: 1.02062
# [2800]	training's rmse: 0.525842	valid_1's rmse: 1.02018
# [2900]	training's rmse: 0.515765	valid_1's rmse: 1.02029
# Early stopping, best iteration is:
# [2808]	training's rmse: 0.525028	valid_1's rmse: 1.02013
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.18242	valid_1's rmse: 1.21419
# [200]	training's rmse: 1.02314	valid_1's rmse: 1.09283
# [300]	training's rmse: 0.956248	valid_1's rmse: 1.0594
# [400]	training's rmse: 0.91295	valid_1's rmse: 1.0438
# [500]	training's rmse: 0.882035	valid_1's rmse: 1.03655
# [600]	training's rmse: 0.856576	valid_1's rmse: 1.03116
# [700]	training's rmse: 0.833598	valid_1's rmse: 1.02682
# [800]	training's rmse: 0.811884	valid_1's rmse: 1.02357
# [900]	training's rmse: 0.793006	valid_1's rmse: 1.02138
# [1000]	training's rmse: 0.776462	valid_1's rmse: 1.01976
# [1100]	training's rmse: 0.757856	valid_1's rmse: 1.01676
# [1200]	training's rmse: 0.741393	valid_1's rmse: 1.01438
# [1300]	training's rmse: 0.725247	valid_1's rmse: 1.01255
# [1400]	training's rmse: 0.710625	valid_1's rmse: 1.01113
# [1500]	training's rmse: 0.696228	valid_1's rmse: 1.01008
# [1600]	training's rmse: 0.682008	valid_1's rmse: 1.00904
# [1700]	training's rmse: 0.668297	valid_1's rmse: 1.008
# [1800]	training's rmse: 0.654567	valid_1's rmse: 1.00726
# [1900]	training's rmse: 0.639746	valid_1's rmse: 1.00628
# [2000]	training's rmse: 0.626551	valid_1's rmse: 1.00572
# [2100]	training's rmse: 0.613964	valid_1's rmse: 1.00509
# [2200]	training's rmse: 0.60207	valid_1's rmse: 1.00439
# [2300]	training's rmse: 0.590587	valid_1's rmse: 1.0035
# [2400]	training's rmse: 0.579823	valid_1's rmse: 1.00281
# [2500]	training's rmse: 0.56852	valid_1's rmse: 1.00203
# [2600]	training's rmse: 0.556918	valid_1's rmse: 1.00172
# [2700]	training's rmse: 0.545916	valid_1's rmse: 1.00125
# [2800]	training's rmse: 0.535977	valid_1's rmse: 1.00067
# [2900]	training's rmse: 0.525759	valid_1's rmse: 1.00046
# [3000]	training's rmse: 0.516131	valid_1's rmse: 1.00011
# [3100]	training's rmse: 0.50668	valid_1's rmse: 0.999719
# [3200]	training's rmse: 0.496968	valid_1's rmse: 0.999575
# [3300]	training's rmse: 0.487664	valid_1's rmse: 0.998915
# [3400]	training's rmse: 0.479423	valid_1's rmse: 0.998717
# [3500]	training's rmse: 0.470844	valid_1's rmse: 0.998578
# [3600]	training's rmse: 0.46278	valid_1's rmse: 0.998282
# [3700]	training's rmse: 0.455674	valid_1's rmse: 0.998131
# Early stopping, best iteration is:
# [3699]	training's rmse: 0.455775	valid_1's rmse: 0.998122
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.18798	valid_1's rmse: 1.20362
# [200]	training's rmse: 1.02953	valid_1's rmse: 1.07355
# [300]	training's rmse: 0.965971	valid_1's rmse: 1.04012
# [400]	training's rmse: 0.922818	valid_1's rmse: 1.02555
# [500]	training's rmse: 0.893654	valid_1's rmse: 1.01891
# [600]	training's rmse: 0.870212	valid_1's rmse: 1.01395
# [700]	training's rmse: 0.846138	valid_1's rmse: 1.01032
# [800]	training's rmse: 0.823442	valid_1's rmse: 1.00691
# [900]	training's rmse: 0.803842	valid_1's rmse: 1.00441
# [1000]	training's rmse: 0.784881	valid_1's rmse: 1.00296
# [1100]	training's rmse: 0.767221	valid_1's rmse: 1.00118
# [1200]	training's rmse: 0.750306	valid_1's rmse: 0.999588
# [1300]	training's rmse: 0.734103	valid_1's rmse: 0.998469
# [1400]	training's rmse: 0.717626	valid_1's rmse: 0.997046
# [1500]	training's rmse: 0.700762	valid_1's rmse: 0.996041
# [1600]	training's rmse: 0.686711	valid_1's rmse: 0.99553
# [1700]	training's rmse: 0.673023	valid_1's rmse: 0.994941
# [1800]	training's rmse: 0.658554	valid_1's rmse: 0.994099
# [1900]	training's rmse: 0.645084	valid_1's rmse: 0.993742
# Early stopping, best iteration is:
# [1872]	training's rmse: 0.648553	valid_1's rmse: 0.993679
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.1776	valid_1's rmse: 1.23677
# [200]	training's rmse: 1.01705	valid_1's rmse: 1.12289
# [300]	training's rmse: 0.952059	valid_1's rmse: 1.09439
# [400]	training's rmse: 0.908265	valid_1's rmse: 1.08077
# [500]	training's rmse: 0.877116	valid_1's rmse: 1.07269
# [600]	training's rmse: 0.850481	valid_1's rmse: 1.06676
# [700]	training's rmse: 0.82647	valid_1's rmse: 1.06213
# [800]	training's rmse: 0.805978	valid_1's rmse: 1.05913
# [900]	training's rmse: 0.785681	valid_1's rmse: 1.05608
# [1000]	training's rmse: 0.766369	valid_1's rmse: 1.05436
# [1100]	training's rmse: 0.748591	valid_1's rmse: 1.05205
# [1200]	training's rmse: 0.731665	valid_1's rmse: 1.05002
# [1300]	training's rmse: 0.714453	valid_1's rmse: 1.04879
# [1400]	training's rmse: 0.697408	valid_1's rmse: 1.04744
# [1500]	training's rmse: 0.682013	valid_1's rmse: 1.04634
# [1600]	training's rmse: 0.66651	valid_1's rmse: 1.04561
# [1700]	training's rmse: 0.652709	valid_1's rmse: 1.04529
# [1800]	training's rmse: 0.639398	valid_1's rmse: 1.04464
# [1900]	training's rmse: 0.62602	valid_1's rmse: 1.04361
# [2000]	training's rmse: 0.61406	valid_1's rmse: 1.04308
# [2100]	training's rmse: 0.600855	valid_1's rmse: 1.04272
# [2200]	training's rmse: 0.588223	valid_1's rmse: 1.04256
# [2300]	training's rmse: 0.575791	valid_1's rmse: 1.04265
# Early stopping, best iteration is:
# [2232]	training's rmse: 0.583971	valid_1's rmse: 1.04248
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.18273	valid_1's rmse: 1.22507
# [200]	training's rmse: 1.02173	valid_1's rmse: 1.10358
# [300]	training's rmse: 0.956931	valid_1's rmse: 1.06748
# [400]	training's rmse: 0.916202	valid_1's rmse: 1.05281
# [500]	training's rmse: 0.88489	valid_1's rmse: 1.04439
# [600]	training's rmse: 0.859438	valid_1's rmse: 1.03943
# [700]	training's rmse: 0.83618	valid_1's rmse: 1.03555
# [800]	training's rmse: 0.815634	valid_1's rmse: 1.03239
# [900]	training's rmse: 0.796173	valid_1's rmse: 1.03005
# [1000]	training's rmse: 0.778144	valid_1's rmse: 1.02776
# [1100]	training's rmse: 0.760562	valid_1's rmse: 1.02624
# [1200]	training's rmse: 0.74264	valid_1's rmse: 1.02435
# [1300]	training's rmse: 0.727492	valid_1's rmse: 1.02394
# [1400]	training's rmse: 0.712047	valid_1's rmse: 1.02302
# [1500]	training's rmse: 0.695916	valid_1's rmse: 1.02128
# [1600]	training's rmse: 0.681795	valid_1's rmse: 1.02046
# [1700]	training's rmse: 0.667483	valid_1's rmse: 1.01952
# [1800]	training's rmse: 0.653345	valid_1's rmse: 1.01936
# [1900]	training's rmse: 0.638398	valid_1's rmse: 1.01858
# [2000]	training's rmse: 0.625167	valid_1's rmse: 1.01815
# [2100]	training's rmse: 0.61113	valid_1's rmse: 1.01782
# [2200]	training's rmse: 0.598264	valid_1's rmse: 1.01771
# Early stopping, best iteration is:
# [2153]	training's rmse: 0.60379	valid_1's rmse: 1.0174
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.18301	valid_1's rmse: 1.22139
# [200]	training's rmse: 1.02441	valid_1's rmse: 1.10975
# [300]	training's rmse: 0.960401	valid_1's rmse: 1.08163
# [400]	training's rmse: 0.922472	valid_1's rmse: 1.06949
# [500]	training's rmse: 0.892961	valid_1's rmse: 1.06066
# [600]	training's rmse: 0.865748	valid_1's rmse: 1.05457
# [700]	training's rmse: 0.844267	valid_1's rmse: 1.04951
# [800]	training's rmse: 0.823441	valid_1's rmse: 1.04664
# [900]	training's rmse: 0.803483	valid_1's rmse: 1.04326
# [1000]	training's rmse: 0.783919	valid_1's rmse: 1.04025
# [1100]	training's rmse: 0.76522	valid_1's rmse: 1.03765
# [1200]	training's rmse: 0.748718	valid_1's rmse: 1.03598
# [1300]	training's rmse: 0.730717	valid_1's rmse: 1.03425
# [1400]	training's rmse: 0.71544	valid_1's rmse: 1.03234
# [1500]	training's rmse: 0.699222	valid_1's rmse: 1.03065
# [1600]	training's rmse: 0.685379	valid_1's rmse: 1.02908
# [1700]	training's rmse: 0.670192	valid_1's rmse: 1.0282
# [1800]	training's rmse: 0.655386	valid_1's rmse: 1.02668
# [1900]	training's rmse: 0.640746	valid_1's rmse: 1.02535
# [2000]	training's rmse: 0.627618	valid_1's rmse: 1.02529
# [2100]	training's rmse: 0.613828	valid_1's rmse: 1.02488
# [2200]	training's rmse: 0.600672	valid_1's rmse: 1.02394
# [2300]	training's rmse: 0.588843	valid_1's rmse: 1.02259
# [2400]	training's rmse: 0.577094	valid_1's rmse: 1.02205
# [2500]	training's rmse: 0.565444	valid_1's rmse: 1.02117
# Early stopping, best iteration is:
# [2499]	training's rmse: 0.565515	valid_1's rmse: 1.02114
# Training until validation scores don't improve for 100 rounds
# [100]	training's rmse: 1.18285	valid_1's rmse: 1.2127
# [200]	training's rmse: 1.02391	valid_1's rmse: 1.09181
# [300]	training's rmse: 0.95805	valid_1's rmse: 1.05877
# [400]	training's rmse: 0.916092	valid_1's rmse: 1.04548
# [500]	training's rmse: 0.884698	valid_1's rmse: 1.03787
# [600]	training's rmse: 0.859184	valid_1's rmse: 1.03279
# [700]	training's rmse: 0.835568	valid_1's rmse: 1.02921
# [800]	training's rmse: 0.813353	valid_1's rmse: 1.02455
# [900]	training's rmse: 0.794161	valid_1's rmse: 1.02175
# [1000]	training's rmse: 0.776714	valid_1's rmse: 1.0197
# [1100]	training's rmse: 0.758456	valid_1's rmse: 1.01742
# [1200]	training's rmse: 0.741203	valid_1's rmse: 1.01566
# [1300]	training's rmse: 0.728555	valid_1's rmse: 1.01485
# [1400]	training's rmse: 0.71261	valid_1's rmse: 1.01321
# [1500]	training's rmse: 0.6981	valid_1's rmse: 1.0116
# [1600]	training's rmse: 0.683994	valid_1's rmse: 1.01063
# [1700]	training's rmse: 0.670458	valid_1's rmse: 1.00926
# [1800]	training's rmse: 0.656485	valid_1's rmse: 1.00854
# [1900]	training's rmse: 0.643067	valid_1's rmse: 1.00772
# [2000]	training's rmse: 0.630806	valid_1's rmse: 1.007
# [2100]	training's rmse: 0.61787	valid_1's rmse: 1.00601
# [2200]	training's rmse: 0.605127	valid_1's rmse: 1.00555
# [2300]	training's rmse: 0.592817	valid_1's rmse: 1.00484
# [2400]	training's rmse: 0.581512	valid_1's rmse: 1.00424
# [2500]	training's rmse: 0.571323	valid_1's rmse: 1.0037
# [2600]	training's rmse: 0.560166	valid_1's rmse: 1.0029
# [2700]	training's rmse: 0.550283	valid_1's rmse: 1.00212
# [2800]	training's rmse: 0.539982	valid_1's rmse: 1.00177
# [2900]	training's rmse: 0.530977	valid_1's rmse: 1.0012
# [3000]	training's rmse: 0.520744	valid_1's rmse: 1.00054
# [3100]	training's rmse: 0.510044	valid_1's rmse: 1.00014
# [3200]	training's rmse: 0.499862	valid_1's rmse: 0.999881
# [3300]	training's rmse: 0.489341	valid_1's rmse: 0.999757
# [3400]	training's rmse: 0.481228	valid_1's rmse: 0.999618
# [3500]	training's rmse: 0.472172	valid_1's rmse: 0.999333
# [3600]	training's rmse: 0.463735	valid_1's rmse: 0.999265
# Early stopping, best iteration is:
# [3581]	training's rmse: 0.465191	valid_1's rmse: 0.999131

# %%
def show_feature_importance(models, feat_train_df) -> plotly.graph_objects.Figure:
    '''LightGBMのfeature importanceを可視化
    '''
    feature_importance_df = pd.DataFrame()
    for i, model in enumerate(models):
        _df = pd.DataFrame()
        _df['feature_importance'] = model.feature_importance(importance_type="gain")
        _df['feature'] = feat_train_df.columns
        _df['fold'] = i + 1
        feature_importance_df = pd.concat([feature_importance_df, _df], 
                                          axis=0, ignore_index=True)

    order = feature_importance_df.groupby('feature')\
        .sum()[['feature_importance']]\
        .sort_values('feature_importance', ascending=False).index[:50]
    
    fig = px.box(
        feature_importance_df.query("feature in @order"),
        x="feature_importance",
        y="feature",
        category_orders={"feature": order},
        width=1250,
        height=900,
        title="Top 50 feature importance",
    )
    fig.update_yaxes(showgrid=True)

    return fig


def show_oof_predict_distribution(y_train: np.ndarray, y_oof: np.ndarray, y_pred: np.ndarray) -> plotly.graph_objects.Figure:
    '''train, oof, predのhistogramを可視化する
    '''
    dfs = [pd.DataFrame({'phase': phase, 'value': value}) for phase, value in zip(['train', 'oof', 'pred'], [y_train, y_oof, y_pred])]
    df = pd.concat(dfs, axis=0)
    fig = px.histogram(df, x="value", color="phase", width=1250, marginal="box")
    fig.update_layout(barmode="overlay")
    fig.update_traces(opacity=0.6, marker=dict(line=dict(width=2,color="DarkSlateGrey")))

    return fig

# %%
fig = show_feature_importance(models, X_train)
fig.show()

# %%
fig = show_oof_predict_distribution(y_train, y_oof, y_pred)
fig.show()

# %%
def revert_log_target(y_log: np.ndarray) -> np.ndarray:
    y = np.expm1(y_log)
    y = np.where(y < 0, 0, y)
    return y


def make_submit(submission: pd.DataFrame, y_pred: np.ndarray, path: str, f_name: str):
    dir_path = Path(path)
    submission_df = submission.copy()
    submission_df["likes"] = y_pred
    assert len(submission_df) == len(y_pred)

    submission_df.to_csv(dir_path / str(f_name + ".csv"), index=False)

# %%
revert_pred = revert_log_target(y_pred)
make_submit(art_ds.submission, revert_pred, OUTPUT_DIR, EXP_NAME)
